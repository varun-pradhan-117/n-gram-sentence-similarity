# %%
import re
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import tensorflow_hub as hub
import tensorflow as tf 
import fasttext.util
nltk.download('punkt')

class FTsimilarityChecker():

    # init dunder to load model  
    def __init__(self):
        #self.url= url
        self.model = fasttext.load_model('FastText Model/cc.en.300.bin')
        self.sentence_list=[]

    # Function to generate a list of unigrams, bigrams and trigrams of given sentence
    def generate_ngrams(self,sentence_tokens):
        ngram_list=[]
        for i in range(1,4): 
            grams=list(ngrams(sentence_tokens,i))
            
            ngram_list.append([' '.join(gram) for gram in grams])
        return ngram_list
    
    # Function to take a list of sentences as input and store their tokens, lengths, ngrams and embeddings
    def set_sentences(self,sentence_list):
        self.sentence_list=list(sentence_list)
        self.cleaned_list=[self.clean_sentence(sentence) for sentence in sentence_list]
        self.sentence_lens=[len(sentence) for sentence in self.cleaned_list]
        self.ngram_list=[self.generate_ngrams(tokenized_sentence) for tokenized_sentence in self.cleaned_list]
        self.embedded_sentences=[self.embed_ngrams(grams) for grams in self.ngram_list]

    # Function to get embeddings for given unigrams, bigrams and trigrams and return as list
    '''
    def embed_ngrams(self,ngram_list):
        emb_ngrams=[]
        #emb_ngrams=np.arr
        for grams in ngram_list:
            embedded_grams=np.array(self.model(grams))
            emb_ngrams.append(embedded_grams)
        return emb_ngrams
    '''
    def get_norm_vector(self,gram):
        sentence_vector=self.model.get_sentence_vector(gram)
        norm_vector=sentence_vector/np.linalg.norm(sentence_vector)
        return norm_vector

    def embed_ngrams(self,ngram_list):
        emb_list=[]
        for grams in ngram_list:
            if len(grams):
                embeds=np.array(list(map(self.get_norm_vector, grams)))
                emb_list.append(embeds)
        return emb_list

    # Function to clean a sentence and return as tokens
    def clean_sentence(self,sentence):
        sentence=re.sub(r"[^a-zA-Z']", ' ', sentence)
        sentence=re.sub(r"[^a-zA-Z ]", '', sentence)
        return word_tokenize(sentence)

    # Function to get similarity score for given n-gram samples
      ## Since USE returns normalized vectors, the cosine similarity can be calculated through the dot product of two vectors  
      ## The dot product is calculated by matrix multiplication of sentence 1 n-grams with the transpose of sentence 2 n-grams  
      ## Max of all values is taken on the horizontal axis to get the maximum similarity for each n-gram  
      ## Score is calculated by getting the sum of similarities and dividing by number of n-grams in sentence 1
    def get_score(self,emb1,emb2):
        
        # Get number of ngrams in sentence 1
        N1=len(emb1)
        
        ## Get cosine similarity between n-grams
        ## This is done by getting dot product of n-grams of sentence 1 with n-grams of sentence 2
        try:
            sim_matrix=np.matmul(emb1,emb2.T)
        except:
            sim_matrix=0

        ## Get maximum similarity score as match
        try:
            max_sim=np.max(sim_matrix,axis=1)
        except:
            max_sim=0
        
        ## Get score by dividing sum by number of n-grams in sentence 1
        score=np.sum(max_sim)/N1
        return score

    # Function to calculate similarity score for 2 embedded sentences
    def get_sim_score(self,embeds1,embeds2):
        final_score=0
        # Score has to be divided by sum of length of n-grams i.e. 1+2+3
        div=0
        for i in range(0,min(len(embeds1),len(embeds2))):
          
          scoren=self.get_score(embeds1[i],embeds2[i])
          print(f'{i+1}-gram score: {scoren}')
          
          # Multiply scoren with weight and add to final score
          if scoren != 0:
            final_score+=(i+1)*scoren
            div+= i+1
        return final_score/div

    # Function to find the stored sentence that is most similar to input
    def best_sim(self,sentence):
        cleaned_input=self.clean_sentence(sentence)
        input_ngrams=self.generate_ngrams(cleaned_input)
        input_emb_ngrams=self.embed_ngrams(input_ngrams)
        input_len=len(cleaned_input)
        score_list=[]
        for i in range(0,len(self.sentence_list)):
          print(f'Comparing with : {self.sentence_list[i]}')
          if input_len>self.sentence_lens[i]:
            score=self.get_sim_score(input_emb_ngrams,self.embedded_sentences[i])
          else:
            score=self.get_sim_score(self.embedded_sentences[i],input_emb_ngrams)
          print("Final score = ",score)
          print('-----------------------')
          score_list.append(score)
        # Select highest similarity score
        best_score=max(score_list)
        # Get sentence with highest similarity
        best_sentence=self.sentence_list[score_list.index(best_score)]
        return best_sentence,best_score

    # Function to compare 2 input sentences and give similarity score
    def compare_sentences(self,sentence1,sentence2):
        # Clean both sentences
        cleaned_sent1=self.clean_sentence(sentence1)
        cleaned_sent2=self.clean_sentence(sentence2)

        # Make sure sentence 1 is the longer sentence
        if len(cleaned_sent2)>len(cleaned_sent1):
          cleaned_sent1,cleaned_sent2=cleaned_sent2,cleaned_sent1

        # Generate ngrams for both sentences
        sent1_ngrams=self.generate_ngrams(cleaned_sent1)
        sent2_ngrams=self.generate_ngrams(cleaned_sent2)

        # Embed ngrams for both sentences
        sent1_emb_ngrams=self.embed_ngrams(sent1_ngrams)
        sent2_emb_ngrams=self.embed_ngrams(sent2_ngrams)

        # Calculate and return similarity score
        final_score=self.get_sim_score(sent1_emb_ngrams,sent2_emb_ngrams)
        print(f'Similarity between "{sentence1}" and "{sentence2} = {final_score}')
        return final_score

    # Function to find best similarity with user entered list of sentences
    def best_from_list(self,sentence1,sentences):
        # Clean list of sentences
        cleaned_list=[self.clean_sentence(sentence) for sentence in sentences]
        sentence_lens=[len(sentence) for sentence in cleaned_list]
        ngram_list=[self.generate_ngrams(tokenized_sentence) for tokenized_sentence in cleaned_list]
        embedded_sentences=[self.embed_ngrams(grams) for grams in ngram_list]

        # Clean sentence 1
        cleaned_input=self.clean_sentence(sentence1)
        input_ngrams=self.generate_ngrams(cleaned_input)
        input_emb_ngrams=self.embed_ngrams(input_ngrams)
        input_len=len(cleaned_input)
        score_list=[]
        for i in range(0,len(sentences)):
          print(f'Comparing with : {sentences[i]}')
          if input_len>=sentence_lens[i]:
            score=self.get_sim_score(input_emb_ngrams,embedded_sentences[i])
          else:
            score=self.get_sim_score(embedded_sentences[i],input_emb_ngrams)
          print("Final score = ",score)
          print('-----------------------')
          score_list.append(score)
        # Select highest similarity score
        best_score=max(score_list)
        # Get sentence with highest similarity
        best_sentence=sentences[score_list.index(best_score)]
        return best_sentence,best_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Download Fasttext model

# %%
#fasttext.util.download_model('en', if_exists='ignore')

# %% [markdown]
# ### Create class object

# %%
checker=FTsimilarityChecker()
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# ### Initialize sentence list

# %%
sentences=["Cancel my order",
           "Show recent items",
           "Show my orders",
           "Track my order",
           "Confirm my order"]
checker.set_sentences(sentences)

# %%
checker.ngram_list
# Out:
# [[['Cancel', 'my', 'order'], ['Cancel my', 'my order'], ['Cancel my order']],
#  [['Show', 'recent', 'items'],
#   ['Show recent', 'recent items'],
#   ['Show recent items']],
#  [['Show', 'my', 'orders'], ['Show my', 'my orders'], ['Show my orders']],
#  [['Track', 'my', 'order'], ['Track my', 'my order'], ['Track my order']],
#  [['Confirm', 'my', 'order'],
#   ['Confirm my', 'my order'],
#   ['Confirm my order']]]

# %% [markdown]
# ### Check similarity for various sentences

# %%
checker.compare_sentences('Hello world',"Hello world")
# Out:
# 1-gram score: 0.9999999403953552
# 2-gram score: 1.0
# Similarity between "Hello world" and "Hello world = 0.999999980131785
# 0.999999980131785

# %%
sentence,score=checker.best_sim("Cancel my order")
print(f'Highest similarity with "{sentence}" with score = {score}')
# Out:
# Comparing with : Cancel my order
# 1-gram score: 1.0
# 2-gram score: 0.9999998807907104
# 3-gram score: 1.0
# Final score =  0.9999999602635702
# -----------------------
# Comparing with : Show recent items
# 1-gram score: 0.2643624146779378
# 2-gram score: 0.30793842673301697
# 3-gram score: 0.3360864520072937
# Final score =  0.3147497706943088
# -----------------------
# Comparing with : Show my orders
# 1-gram score: 0.6095080773035685
# 2-gram score: 0.7331385612487793
# 3-gram score: 0.644798219203949
# Final score =  0.668363309568829
# -----------------------
# Comparing with : Track my order
# 1-gram score: 0.7109317779541016
# 2-gram score: 0.8036900758743286
# 3-gram score: 0.7677028775215149
# Final score =  0.7702367603778839
# -----------------------
# Comparing with : Confirm my order
# 1-gram score: 0.7908719380696615
# 2-gram score: 0.8587917685508728
# 3-gram score: 0.8389230966567993
# Final score =  0.8375374608569676
# -----------------------
# Highest similarity with "Cancel my order" with score = 0.9999999602635702

# %%
checker.best_sim("I don't want my package")
# Out:
# Comparing with : Cancel my order
# 1-gram score: 0.4870284557342529
# 2-gram score: 0.5441968441009521
# 3-gram score: 0.5295750300089518
# Final score =  0.5273578723271688
# -----------------------
# Comparing with : Show recent items
# 1-gram score: 0.17735130786895753
# 2-gram score: 0.17905811965465546
# 3-gram score: 0.19400978088378906
# Final score =  0.1862494816382726
# -----------------------
# Comparing with : Show my orders
# 1-gram score: 0.4551896095275879
# 2-gram score: 0.46752655506134033
# 3-gram score: 0.43185075124104816
# Final score =  0.4476324955622355
# -----------------------
# Comparing with : Track my order
# 1-gram score: 0.4870284557342529
# 2-gram score: 0.5410385131835938
# 3-gram score: 0.4684861898422241
# Final score =  0.49576067527135215
# -----------------------
# Comparing with : Confirm my order
# 1-gram score: 0.4870284557342529
# 2-gram score: 0.5453283786773682
# 3-gram score: 0.5475306510925293
# Final score =  0.5367128610610962
# -----------------------
# ('Confirm my order', 0.5367128610610962)

# %%
checker.compare_sentences("I hope you have read my mail","I hope you received my mail")
# Out:
# 1-gram score: 0.8520445823669434
# 2-gram score: 0.8508358796437582
# 3-gram score: 0.8616189956665039
# Similarity between "I hope you have read my mail" and "I hope you received my mail = 0.8564288881089953
# 0.8564288881089953

# %% [markdown]
# ## Loading Test data

# %%
import pandas as pd
import unicodedata

# %%
data=pd.read_csv('Data/similarity-testing-data.csv')

# %%
data.columns
# Out:
# Index(['Alias', 'Label'], dtype='object')

# %%
aliases=list(data['Alias'])
labels=list(data['Label'])

# %%
aliases=[unicodedata.normalize("NFKD", alias) for alias in aliases]

# %%
labels=[unicodedata.normalize("NFKD", label) for label in labels]

# %%
len(labels),len(aliases)
# Out:
# (316, 316)

# %%
set(labels)
# Out:
# {'Add my address',
#  'Add to cart',
#  'Add to wishlist',
#  'Cancel my order',
#  'Check my points',
#  'Check working hours',
#  'Find stores nearby',
#  'Get membership',
#  'How to pay',
#  'Place an order',
#  'Search for items',
#  'Show bestsellers',
#  'Show big deals',
#  'Show cart',
#  'Show contact information',
#  'Show my orders',
#  'Show product information',
#  'Show recent items',
#  'Show reservation',
#  'Show return policy',
#  'Track my order',
#  'Use my coupons',
#  'View new arrivals',
#  'Write a complaint',
#  'Write a review'}

# %%
checker.set_sentences(set(labels))

# %%
type(checker.sentence_list)
# Out:
# list

# %%
checker.best_sim('Hello my order')
# Out:
# Comparing with : Show recent items
# 1-gram score: 0.23769301176071167
# 2-gram score: 0.28698933124542236
# 3-gram score: 0.30486783385276794
# Final score =  0.28771252930164337
# -----------------------
# Comparing with : Add to wishlist
# 1-gram score: 0.287508487701416
# 2-gram score: 0.4982783794403076
# 3-gram score: 0.4846133291721344
# Final score =  0.45631753901640576
# -----------------------
# Comparing with : Show cart
# 1-gram score: 0.21007925271987915
# 2-gram score: 0.2145421802997589
# Final score =  0.21305453777313232
# -----------------------
# Comparing with : Search for items
# 1-gram score: 0.2623240152994792
# 2-gram score: 0.3414364457130432
# 3-gram score: 0.34922072291374207
# Final score =  0.3321431792444653
# -----------------------
# Comparing with : Show reservation
# 1-gram score: 0.16774451732635498
# 2-gram score: 0.16436296701431274
# Final score =  0.16549015045166016
# -----------------------
# Comparing with : Cancel my order
# 1-gram score: 0.7288436889648438
# 2-gram score: 0.8286188244819641
# 3-gram score: 0.789393424987793
# Final score =  0.7923769354820251
# -----------------------
# Comparing with : Track my order
# 1-gram score: 0.7085002263387045
# 2-gram score: 0.8089204430580139
# 3-gram score: 0.7663413882255554
# Final score =  0.7708942128552332
# -----------------------
# Comparing with : Show my orders
# 1-gram score: 0.5828386942545573
# 2-gram score: 0.7307517528533936
# 3-gram score: 0.6495197415351868
# Final score =  0.6654835707611507
# -----------------------
# Comparing with : Show return policy
# 1-gram score: 0.23508334159851074
# 2-gram score: 0.3216589093208313
# 3-gram score: 0.3127140998840332
# Final score =  0.30275724331537884
# -----------------------
# Comparing with : Check working hours
# 1-gram score: 0.2075897455215454
# 2-gram score: 0.331598162651062
# 3-gram score: 0.36798444390296936
# Final score =  0.32912323375542957
# -----------------------
# Comparing with : Show product information
# 1-gram score: 0.2271514336268107
# 2-gram score: 0.2566452622413635
# 3-gram score: 0.27099305391311646
# Final score =  0.2589035199748145
# -----------------------
# Comparing with : Place an order
# 1-gram score: 0.5051333904266357
# 2-gram score: 0.532101571559906
# 3-gram score: 0.5541179776191711
# Final score =  0.5386150777339935
# -----------------------
# Comparing with : Show big deals
# 1-gram score: 0.18734542528788248
# 2-gram score: 0.2281785011291504
# 3-gram score: 0.20820888876914978
# Final score =  0.21138818230893874
# -----------------------
# Comparing with : Use my coupons
# 1-gram score: 0.46076369285583496
# 2-gram score: 0.6442242860794067
# 3-gram score: 0.5393707752227783
# Final score =  0.5612207651138306
# -----------------------
# Comparing with : Get membership
# 1-gram score: 0.18507403135299683
# 2-gram score: 0.21385405957698822
# Final score =  0.20426071683565775
# -----------------------
# Comparing with : How to pay
# 1-gram score: 0.337591012318929
# 2-gram score: 0.48850613832473755
# 3-gram score: 0.4616926312446594
# Final score =  0.44994686378373033
# -----------------------
# Comparing with : Show bestsellers
# 1-gram score: 0.11582320928573608
# 2-gram score: 0.13195675611495972
# Final score =  0.12657890717188516
# -----------------------
# Comparing with : Find stores nearby
# 1-gram score: 0.15326233704884848
# 2-gram score: 0.18132635951042175
# 3-gram score: 0.17495854198932648
# Final score =  0.17346511367294526
# -----------------------
# Comparing with : Add my address
# 1-gram score: 0.5023341178894043
# 2-gram score: 0.6894094944000244
# 3-gram score: 0.6385083794593811
# Final score =  0.6327797075112661
# -----------------------
# Comparing with : View new arrivals
# 1-gram score: 0.17165406545003256
# 2-gram score: 0.263364315032959
# 3-gram score: 0.29933464527130127
# Final score =  0.26606443855497575
# -----------------------
# Comparing with : Show contact information
# 1-gram score: 0.21961156527201334
# 2-gram score: 0.24570560455322266
# 3-gram score: 0.28099119663238525
# Final score =  0.2589993940459357
# -----------------------
# Comparing with : Write a complaint
# 1-gram score: 0.28883663813273114
# 2-gram score: 0.40833884477615356
# 3-gram score: 0.4273032248020172
# Final score =  0.39790400034851503
# -----------------------
# Comparing with : Check my points
# 1-gram score: 0.448406179745992
# 2-gram score: 0.6497935056686401
# 3-gram score: 0.564376950263977
# Final score =  0.5735206736458672
# -----------------------
# Comparing with : Write a review
# 1-gram score: 0.3072855472564697
# 2-gram score: 0.42154744267463684
# 3-gram score: 0.4306409955024719
# Final score =  0.4070505698521932
# -----------------------
# Comparing with : Add to cart
# 1-gram score: 0.30181517203648883
# 2-gram score: 0.5049335956573486
# 3-gram score: 0.4464142918586731
# Final score =  0.44182087315453417
# -----------------------
# ('Cancel my order', 0.7923769354820251)

# %%
correct=0
for i in range(0,len(aliases)):
    sentence,score=checker.best_sim(aliases[i])
    if  sentence==labels[i]:
        print(sentence,labels[i])
        correct+=1
# Out:
# Comparing with : Show recent items
# 1-gram score: 0.26483603318532306
# 2-gram score: 0.29195651412010193
# 3-gram score: 0.34274986386299133
# Final score =  0.31283310883575016
# -----------------------
# Comparing with : Add to wishlist
# 1-gram score: 0.287508487701416
# 2-gram score: 0.4982783794403076
# 3-gram score: 0.468625545501709
# Final score =  0.44832364718119305
# -----------------------
# Comparing with : Show cart
# 1-gram score: 0.23722227414449057
# 2-gram score: 0.251961886882782
# Final score =  0.24704868263668486
# -----------------------
# Comparing with : Search for items
# 1-gram score: 0.25453780094782513
# 2-gram score: 0.3414364457130432
# 3-gram score: 0.3833999037742615
# Final score =  0.34793506728278273
# -----------------------
# Comparing with : Show reservation
# 1-gram score: 0.19488751888275146
# 2-gram score: 0.20559881627559662
# Final score =  0.2020283838113149
# -----------------------
# Comparing with : Cancel my order
# 1-gram score: 0.7088770071665446
# 2-gram score: 0.8067578077316284
# 3-gram score: 0.7591379880905151
# Final score =  0.7666344311502243
# -----------------------
# Comparing with : Track my order
# 1-gram score: 0.7174553871154785
# 2-gram score: 0.8036900758743286
# 3-gram score: 0.7674750089645386
# Final score =  0.7712100942929586
# -----------------------
# Comparing with : Show my orders
# 1-gram score: 0.6099816958109537
# 2-gram score: 0.7345913648605347
# 3-gram score: 0.6689196228981018
# Final score =  0.680987215704388
# -----------------------
# Comparing with : Show return policy
# 1-gram score: 0.2622263431549072
# 2-gram score: 0.3216589093208313
# 3-gram score: 0.37903544306755066
# Final score =  0.3404417484998703
# -----------------------
# Comparing with : Check working hours
# 1-gram score: 0.21449613571166992
# 2-gram score: 0.331598162651062
# 3-gram score: 0.3593054711818695
# Final score =  0.3259348124265671
# -----------------------
# Comparing with : Show product information
# 1-gram score: 0.2542944351832072
# 2-gram score: 0.2566452622413635
# 3-gram score: 0.2903148829936981
# Final score =  0.2730882681078381
# -----------------------
# Comparing with : Place an order
# 1-gram score: 0.5427354971567789
# 2-gram score: 0.532101571559906
# 3-gram score: 0.6012568473815918
# Final score =  0.568451530403561
# -----------------------
# Comparing with : Show big deals
# 1-gram score: 0.2144884467124939
# 2-gram score: 0.23779159784317017
# 3-gram score: 0.2516781985759735
# Final score =  0.24085103968779245
# -----------------------
# Comparing with : Use my coupons
# 1-gram score: 0.4830542008082072
# 2-gram score: 0.6538501977920532
# 3-gram score: 0.5882737636566162
# Final score =  0.5925959812270271
# -----------------------
# Comparing with : Get membership
# 1-gram score: 0.17618876695632935
# 2-gram score: 0.2332015037536621
# Final score =  0.21419725815455118
# -----------------------
# Comparing with : How to pay
# 1-gram score: 0.31923389434814453
# 2-gram score: 0.48850613832473755
# 3-gram score: 0.48028188943862915
# Final score =  0.45618197321891785
# -----------------------
# Comparing with : Show bestsellers
# 1-gram score: 0.1429662307103475
# 2-gram score: 0.15005838871002197
# Final score =  0.14769433604346383
# -----------------------
# Comparing with : Find stores nearby
# 1-gram score: 0.14608563979466757
# 2-gram score: 0.18132635951042175
# 3-gram score: 0.21236084401607513
# Final score =  0.19097014847728944
# -----------------------
# Comparing with : Add my address
# 1-gram score: 0.5023341178894043
# 2-gram score: 0.6750752925872803
# 3-gram score: 0.5957317352294922
# Final score =  0.6066133181254069
# -----------------------
# Comparing with : View new arrivals
# 1-gram score: 0.1632817586263021
# 2-gram score: 0.24473030865192413
# 3-gram score: 0.24770167469978333
# Final score =  0.23264123333825007
# -----------------------
# Comparing with : Show contact information
# 1-gram score: 0.24675456682840982
# 2-gram score: 0.24570560455322266
# 3-gram score: 0.28628772497177124
# Final score =  0.26617149180836147
# -----------------------
# Comparing with : Write a complaint
# 1-gram score: 0.2751368284225464
# 2-gram score: 0.40833884477615356
# 3-gram score: 0.4219032824039459
# Final score =  0.39292072753111523
# -----------------------
# Comparing with : Check my points
# 1-gram score: 0.4553125301996867
# 2-gram score: 0.6424265503883362
# 3-gram score: 0.563816487789154
# Final score =  0.5719358490573035
# -----------------------
# Comparing with : Write a review
# 1-gram score: 0.293585737546285
# 2-gram score: 0.42154744267463684
# 3-gram score: 0.4230809211730957
# Final score =  0.4009872310691409
# -----------------------
# Comparing with : Add to cart
# 1-gram score: 0.30181517203648883
# 2-gram score: 0.5049335956573486
# 3-gram score: 0.46380913257598877
# Final score =  0.450518293513192
# -----------------------
# Comparing with : Show recent items
# 1-gram score: 0
# -----------------------
# Comparing with : Show contact information
# 1-gram score: 0.22821197907129923
# 2-gram score: 0.24570560455322266
# 3-gram score: 0.2873689830303192
# Final score =  0.26362168954478366
# -----------------------
# Comparing with : Write a complaint
# 1-gram score: 0.2727983792622884
# 2-gram score: 0.40833884477615356
# 3-gram score: 0.38759270310401917
# Final score =  0.3753756963544421
# -----------------------
# Comparing with : Check my points
# 1-gram score: 0.4451580047607422
# 2-gram score: 0.6319248676300049
# 3-gram score: 0.537790060043335
# Final score =  0.5537296533584595
# -----------------------
# Comparing with : Write a review
# 1-gram score: 0.29124728838602704
# 2-gram score: 0.42154744267463684
# 3-gram score: 0.3743830919265747
# Final score =  0.37624857491917085
# -----------------------
# Comparing with : Add to cart
# 1-gram score: 0.30181517203648883
# 2-gram score: 0.5049335956573486
# 3-gram score: 0.439906507730484
# Final score =  0.4385669810904396
# -----------------------
# Cancel my order Cancel my order
# Comparing with : Show recent items
# 1-gram score: 0.23678383231163025
# 2-gram score: 0.253326157728831
# 3-gram score: 0.2913673222064972
# Final score =  0.26958968573146397
# -----------------------
# Comparing with : Add to wishlist
# 1-gram score: 0.35689741373062134
# 2-gram score: 0.43912164370218915
# 3-gram score: 0.45954522490501404
# Final score =  0.435629395975007
# -----------------------
# Comparing with : Show cart
# 1-gram score: 0.2155090868473053
# 2-gram score: 0.24589353799819946
# Final score =  0.23576538761456808
# -----------------------
# Comparing with : Search for items
# 1-gram score: 0.26716503500938416
# 2-gram score: 0.3656618595123291
# 3-gram score: 0.3821370601654053
# Final score =  0.3574833224217097
# -----------------------
# Comparing with : Show reservation
# 1-gram score: 0.17276832461357117
# 2-gram score: 0.18816186984380087
# Final score =  0.183030688100391
# -----------------------
# Comparing with : Cancel my order
# 1-gram score: 0.6197693347930908
# 2-gram score: 0.6699228286743164
# 3-gram score: 0.6640982031822205
# Final score =  0.6586516002813975
# -----------------------
# Comparing with : Track my order
# 1-gram score: 0.6447367668151855
# 2-gram score: 0.6701051394144694
# 3-gram score: 0.6687336564064026
# Final score =  0.6651913358105553
# -----------------------
# Comparing with : Show my orders
# 1-gram score: 0.517263650894165
# 2-gram score: 0.5818052291870117
# 3-gram score: 0.5883336067199707
# Final score =  0.5743124882380167
# -----------------------
# Comparing with : Show return policy
# 1-gram score: 0.2463996261358261
# 2-gram score: 0.2897602319717407
# 3-gram score: 0.3156828284263611
# Final score =  0.2954947625597318
# -----------------------
# Comparing with : Check working hours
# 1-gram score: 0.2944645583629608
# 2-gram score: 0.4163216749827067
# 3-gram score: 0.46520179510116577
# Final score =  0.42045221560531193
# -----------------------
# Comparing with : Show product information
# 1-gram score: 0.1995399296283722
# 2-gram score: 0.23389379183451334
# 3-gram score: 0.2641623616218567
# Final score =  0.24330243302716148
# -----------------------
# Comparing with : Place an order
# 1-gram score: 0.4853586256504059
# 2-gram score: 0.49192118644714355
# 3-gram score: 0.5156099796295166
# Final score =  0.5026718229055405
# -----------------------
# Comparing with : Show big deals
# 1-gram score: 0.2183571606874466
# 2-gram score: 0.2915675640106201
# 3-gram score: 0.3344981074333191
# Final score =  0.300831101834774
# -----------------------
# Comparing with : Use my coupons
# 1-gram score: 0.4655386507511139
# 2-gram score: 0.5590926806131998
# 3-gram score: 0.5727235078811646
# Final score =  0.5503157559368345
# -----------------------
# Comparing with : Get membership
# 1-gram score: 0.26505449414253235
# 2-gram score: 0.28934748967488605
# Final score =  0.2812498244974348
# -----------------------
# Comparing with : How to pay
# 1-gram score: 0.32718464732170105
# 2-gram score: 0.40344611803690594
# 3-gram score: 0.4614516496658325
# Final score =  0.41973863873216843
# -----------------------
# Comparing with : Show bestsellers
# 1-gram score: 0.12429173290729523
# 2-gram score: 0.16680991649627686
# Final score =  0.152637188633283
# -----------------------
# Comparing with : Find stores nearby
# 1-gram score: 0.20902766287326813
# 2-gram score: 0.251380721728007
# 3-gram score: 0.29451292753219604
# Final score =  0.2658879814876451
# -----------------------
# Comparing with : Add my address
# 1-gram score: 0.4881686866283417
# 2-gram score: 0.5754812161127726
# 3-gram score: 0.6006626486778259
# Final score =  0.573519844147894
# -----------------------
# Comparing with : View new arrivals
# 1-gram score: 0.21800470352172852
# 2-gram score: 0.2823059757550557
# 3-gram score: 0.2893332242965698
# Final score =  0.2751027213202582
# -----------------------
# Comparing with : Show contact information
# 1-gram score: 0.20381104946136475
# 2-gram score: 0.2502130667368571
# 3-gram score: 0.2748124897480011
# Final score =  0.2547791086965137
# -----------------------
# Comparing with : Write a complaint
# 1-gram score: 0
# -----------------------
# Comparing with : Show product information
# 1-gram score: 0.2701428413391113
# 2-gram score: 0.3273305892944336
# 3-gram score: 0.37965766588846844
# Final score =  0.34396283626556395
# -----------------------
# Comparing with : Place an order
# 1-gram score: 0.26294384002685545
# 2-gram score: 0.3151389956474304
# 3-gram score: 0.3898939291636149
# Final score =  0.34381726980209354
# -----------------------
# Comparing with : Show big deals
# 1-gram score: 0.17805341482162476
# 2-gram score: 0.18843303620815277
# 3-gram score: 0.26073819398880005
# Final score =  0.22285567820072175
# -----------------------
# Comparing with : Use my coupons
# 1-gram score: 0.3447826862335205
# 2-gram score: 0.4510064721107483
# 3-gram score: 0.5235505898793539
# Final score =  0.4695745666821798
# -----------------------
# Comparing with : Get membership
# 1-gram score: 0.1890399932861328
# 2-gram score: 0.1918504238128662
# Final score =  0.19091361363728843
# -----------------------
# Comparing with : How to pay
# 1-gram score: 0.23755488395690919
# 2-gram score: 0.2798447608947754
# 3-gram score: 0.3368039131164551
# Final score =  0.30127602418263755
# -----------------------
# Comparing with : Show bestsellers
# 1-gram score: 0.15790061950683593
# 2-gram score: 0.18222050368785858
# Final score =  0.1741138756275177
# -----------------------
# Comparing with : Find stores nearby
# 1-gram score: 0.2210378408432007
# 2-gram score: 0.23210957646369934
# 3-gram score: 0.260148564974467
# Final score =  0.24428378144900006
# -----------------------
# Comparing with : Add my address
# 1-gram score: 0.3202259063720703
# 2-gram score: 0.41047313809394836
# 3-gram score: 0.5137026309967041
# Final score =  0.44704667925834657
# -----------------------
# Comparing with : View new arrivals
# 1-gram score: 0.2102430820465088
# 2-gram score: 0.28595152497291565
# 3-gram score: 0.2834460735321045
# Final score =  0.2720807254314423
# -----------------------
# Comparing with : Show contact information
# 1-gram score: 0.23764655590057374
# 2-gram score: 0.3090142011642456
# 3-gram score: 0.36248596509297687
# Final score =  0.32385547558466593
# -----------------------
# Comparing with : Write a complaint
# 1-gram score: 0.43240809440612793
# 2-gram score: 0.4066186547279358
# 3-gram score: 0.46631280581156415
# Final score =  0.4407639702161153
# -----------------------
# Comparing with : Check my points
# 1-gram score: 0.29732038974761965
# 2-gram score: 0.41931816935539246
# 3-gram score: 0.5243250528971354
# Final score =  0.4514886478583018
# -----------------------
# Comparing with : Write a review
# 1-gram score: 0.4718674659729004
# 2-gram score: 0.4348694682121277
# 3-gram score: 0.5145790576934814
# Final score =  0.4808905959129333
# -----------------------
# Comparing with : Add to cart
# 1-gram score: 0.33283357620239257
# 2-gram score: 0.35024717450141907
# 3-gram score: 0.4025370279947917
# Final score =  0.37348983486493426
# -----------------------
# Write a review Write a review
# Comparing with : Show recent items
# 1-gram score: 0.25434045791625975
# 2-gram score: 0.3371554911136627
# 3-gram score: 0.3756573994954427
# Final score =  0.3426039397716522
# -----------------------
# Comparing with : Add to wishlist
# 1-gram score: 0.24843935966491698
# 2-gram score: 0.29775652289390564
# 3-gram score: 0.36203618844350177
# Final score =  0.3216768284638723
# -----------------------
# Comparing with : Show cart
# 1-gram score: 0.21571037769317628
# 2-gram score: 0.2438872754573822
# Final score =  0.2344949762026469
# -----------------------
# Comparing with : Search for items
# 1-gram score: 0.2940842866897583
# 2-gram score: 0.3535037934780121
# 3-gram score: 0.4020818869272868
# Final score =  0.36788958907127384
# -----------------------
# Comparing with : Show reservation
# 1-gram score: 0.17209064960479736
# 2-gram score: 0.20320993661880493
# Final score =  0.19283684094746908
# -----------------------
# Comparing with : Cancel my order
# 1-gram score: 0.2500994920730591
# 2-gram score: 0.3578839898109436
# 3-gram score: 0.3971136808395386
# Final score =  0.359534752368927
# -----------------------
# Comparing with : Track my order
# 1-gram score: 0.3361891031265259
# 2-gram score: 0.39486318826675415
# 3-gram score: 0.44269951184590656
# Final score =  0.40900233586629237
# -----------------------
# Comparing with : Show my orders
# 1-gram score: 0.2890953540802002
# 2-gram score: 0.37111514806747437
# 3-gram score: 0.44341198603312176
# Final score =  0.3935936013857524
# -----------------------
# Comparing with : Show return policy
# 1-gram score: 0.20263657569885254
# 2-gram score: 0.24011042714118958
# 3-gram score: 0.3034935196240743
# Final score =  0.2655563314755758
# -----------------------
# Comparing with : Check working hours
# 1-gram score: 0.24625718593597412
# 2-gram score: 0.3378458619117737
# 3-gram score: 0.3955548604329427
# Final score =  0.3514355818430583
# -----------------------
# Comparing with : Show product information
# 1-gram score: 0.3839561939239502
# 2-gram score: 0.3662424683570862
# 3-gram score: 0.4099399248758952
# Final score =  0.391043484210968
# -----------------------
# Comparing with : Place an order
# 1-gram score: 0.2487790107727051
# 2-gram score: 0.2948254942893982
# 3-gram score: 0.3627513249715169
# Final score =  0.3211139957110087
# -----------------------
# Comparing with : Show big deals
# 1-gram score: 0.20007686614990233
# 2-gram score: 0.2107461392879486
# 3-gram score: 0.2707500060399373
# Final score =  0.2389698604742686
# -----------------------
# Comparing with : Use my coupons
# 1-gram score: 0.33625838756561277
# 2-gram score: 0.4213460683822632
# 3-gram score: 0.5087404251098633
# Final score =  0.45086196660995487
# -----------------------
# Comparing with : Get membership
# 1-gram score: 0.13695075511932372
# 2-gram score: 0.17318108677864075
# Final score =  0.16110430955886842
# -----------------------
# Comparing with : How to pay
# 1-gram score: 0.1908280611038208
# 2-gram score: 0.25181999802589417
# 3-gram score: 0.3044784665107727
# Final score =  0.2679839094479879
# -----------------------
# Comparing with : Show bestsellers
# 1-gram score: 0.16986231803894042
# 2-gram score: 0.1862531453371048
# Final score =  0.18078953623771668
# -----------------------
# Comparing with : Find stores nearby
# 1-gram score: 0.18813120126724242
# 2-gram score: 0.22733312845230103
# 3-gram score: 0.25742147366205853
# Final score =  0.2358436465263367
# -----------------------
# Comparing with : Add my address
# 1-gram score: 0.25769546031951907
# 2-gram score: 0.3655153214931488
# 3-gram score: 0.46508018175760907
# Final score =  0.39732777476310727
# -----------------------
# Comparing with : View new arrivals
# 1-gram score: 0.24461765289306642
# 2-gram score: 0.3120420575141907
# 3-gram score: 0.31285421053568524
# Final score =  0.30121073325475056
# -----------------------
# Comparing with : Show contact information
# 1-gram score: 0.2486037492752075
# 2-gram score: 0.3103715777397156
# 3-gram score: 0.3614776134490967
# Final score =  0.32562995751698814
# -----------------------
# Comparing with : Write a complaint
# 1-gram score: 0.2836749076843262
# 2-gram score: 0.331664115190506
# 3-gram score: 0.39574750264485675
# Final score =  0.35570760766665144
# -----------------------
# Comparing with : Check my points
# 1-gram score: 0.2617471694946289
# 2-gram score: 0.3916698098182678
# 3-gram score: 0.5010484059651693
# Final score =  0.42470533450444536
# -----------------------
# Comparing with : Write a review
# 1-gram score: 0.34127976894378664
# 2-gram score: 0.3748524785041809
# 3-gram score: 0.4486929972966512
# Final score =  0.406177286307017
# -----------------------
# Comparing with : Add to cart
# 1-gram score: 0.2723103046417236
# 2-gram score: 0.3151032328605652
# 3-gram score: 0.36880679925282794
# Final score =  0.33482286135355627
# -----------------------

# %%
correct
# Out:
# 160

# %%
len(labels)
# Out:
# 316

# %%
checker.best_sim("Cancel my order")
# Out:
# Comparing with : Show recent items
# 1-gram score: 0.2643624146779378
# 2-gram score: 0.30793842673301697
# 3-gram score: 0.3360864520072937
# Final score =  0.3147497706943088
# -----------------------
# Comparing with : Add to wishlist
# 1-gram score: 0.336869478225708
# 2-gram score: 0.4982783794403076
# 3-gram score: 0.5469393134117126
# Final score =  0.49570736289024353
# -----------------------
# Comparing with : Show cart
# 1-gram score: 0.23674865563710532
# 2-gram score: 0.26266980171203613
# Final score =  0.2540294196870592
# -----------------------
# Comparing with : Search for items
# 1-gram score: 0.315083106358846
# 2-gram score: 0.3414364457130432
# 3-gram score: 0.39321279525756836
# Final score =  0.3629323972596062
# -----------------------
# Comparing with : Show reservation
# 1-gram score: 0.19441392024358115
# 2-gram score: 0.2304058074951172
# Final score =  0.21840851174460518
# -----------------------
# Comparing with : Cancel my order
# 1-gram score: 1.0
# 2-gram score: 0.9999998807907104
# 3-gram score: 1.0
# Final score =  0.9999999602635702
# -----------------------
# Comparing with : Track my order
# 1-gram score: 0.7109317779541016
# 2-gram score: 0.8036900758743286
# 3-gram score: 0.7677028775215149
# Final score =  0.7702367603778839
# -----------------------
# Comparing with : Show my orders
# 1-gram score: 0.6095080773035685
# 2-gram score: 0.7331385612487793
# 3-gram score: 0.644798219203949
# Final score =  0.668363309568829
# -----------------------
# Comparing with : Show return policy
# 1-gram score: 0.26175276438395184
# 2-gram score: 0.3358363211154938
# 3-gram score: 0.38755568861961365
# Final score =  0.34934874541229677
# -----------------------
# Comparing with : Check working hours
# 1-gram score: 0.2145740787188212
# 2-gram score: 0.331598162651062
# 3-gram score: 0.34219691157341003
# Final score =  0.3173935231235292
# -----------------------
# Comparing with : Show product information
# 1-gram score: 0.25382085641225177
# 2-gram score: 0.26193350553512573
# 3-gram score: 0.30099374055862427
# Final score =  0.28011151485972935
# -----------------------
# Comparing with : Place an order
# 1-gram score: 0.5052550633748373
# 2-gram score: 0.532101571559906
# 3-gram score: 0.6131292581558228
# Final score =  0.5681409968270196
# -----------------------
# Comparing with : Show big deals
# 1-gram score: 0.21401484807332358
# 2-gram score: 0.25467514991760254
# 3-gram score: 0.24912633001804352
# Final score =  0.24512402299377656
# -----------------------
# Comparing with : Use my coupons
# 1-gram score: 0.465233047803243
# 2-gram score: 0.6442242860794067
# 3-gram score: 0.529574453830719
# Final score =  0.5570674969090356
# -----------------------
# Comparing with : Get membership
# 1-gram score: 0.17233145236968994
# 2-gram score: 0.23138120770454407
# Final score =  0.21169795592625937
# -----------------------
# Comparing with : How to pay
# 1-gram score: 0.31923389434814453
# 2-gram score: 0.48850613832473755
# 3-gram score: 0.5117571353912354
# Final score =  0.47191959619522095
# -----------------------
# Comparing with : Show bestsellers
# 1-gram score: 0.14249263207117716
# 2-gram score: 0.16532063484191895
# Final score =  0.15771130058500502
# -----------------------
# Comparing with : Find stores nearby
# 1-gram score: 0.16893237829208374
# 2-gram score: 0.18132635951042175
# 3-gram score: 0.19653405249118805
# Final score =  0.18686454246441522
# -----------------------
# Comparing with : Add my address
# 1-gram score: 0.5516951084136963
# 2-gram score: 0.7111632823944092
# 3-gram score: 0.6915401220321655
# Final score =  0.6747736732165018
# -----------------------
# Comparing with : View new arrivals
# 1-gram score: 0.20855794350306192
# 2-gram score: 0.2730953097343445
# 3-gram score: 0.2776291072368622
# Final score =  0.26460598078038955
# -----------------------
# Comparing with : Show contact information
# 1-gram score: 0.24628098805745444
# 2-gram score: 0.25211620330810547
# 3-gram score: 0.28438547253608704
# Final score =  0.26727830204698777
# -----------------------
# Comparing with : Write a complaint
# 1-gram score: 0.3003745476404826
# 2-gram score: 0.4504886567592621
# 3-gram score: 0.46915364265441895
# Final score =  0.43480213152037733
# -----------------------
# Comparing with : Check my points
# 1-gram score: 0.4553904930750529
# 2-gram score: 0.6415265798568726
# 3-gram score: 0.5441892743110657
# Final score =  0.5618352459536659
# -----------------------
# Comparing with : Write a review
# 1-gram score: 0.3188234567642212
# 2-gram score: 0.4813287556171417
# 3-gram score: 0.49830034375190735
# Final score =  0.4627303332090378
# -----------------------
# Comparing with : Add to cart
# 1-gram score: 0.3511761824289958
# 2-gram score: 0.5049335956573486
# 3-gram score: 0.5384117364883423
# Final score =  0.4960464305347867
# -----------------------
# ('Cancel my order', 0.9999999602635702)
